# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prepare for data

# %%
import pandas as pd
import shutil
import os

# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git

# !unzip -q '/content/drive/MyDrive/MEDICAL/Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification.zip' -d '/content/d/'
# !unzip -q '/content/d/ChestXRay2017.zip' -d '/content/d/dd/'

df = pd.read_csv('./covid-chestxray-dataset/metadata.csv')
selected_df = df[df.finding=="Pneumonia/Viral/COVID-19"]
selected_df = selected_df[(selected_df.view == "AP") | (selected_df.view == "PA")]

df = pd.read_csv('./covid-chestxray-dataset/metadata.csv')
selected_df = df[df.finding=="Pneumonia/Viral/COVID-19"]
selected_df = selected_df[(selected_df.view == "AP") | (selected_df.view == "PA")]

images = selected_df.filename.values.tolist()

os.makedirs('./COVID19-DATASET/train/covid19')
os.makedirs('./COVID19-DATASET/train/normal')

COVID_PATH = './COVID19-DATASET/train/covid19'
NORMAL_PATH = './COVID19-DATASET/train/normal'

for image in images:
    shutil.copy(os.path.join('./covid-chestxray-dataset/images', image), os.path.join(COVID_PATH, image))

for image in os.listdir('/content/d/dd/chest_xray/train/NORMAL')[:300]:
    shutil.copy(os.path.join('/content/d/dd/chest_xray/train/NORMAL', image), os.path.join(NORMAL_PATH, image))

TRAIN_PATH = '/content/COVID19-DATASET/train'

print("TRAIN_PATH: {}".format(TRAIN_PATH))

# !unzip -q '/content/drive/MyDrive/MEDICAL/COVID-19_Radiography_Database.zip' -d '/content/covid19-radiography-database/'

os.makedirs('./COVID19-DATASET/test/covid19')
os.makedirs('./COVID19-DATASET/test/normal')

COVID_TEST = '/content/covid19-radiography-database/COVID-19_Radiography_Dataset/COVID'
NORMAL_TEST = '/content/covid19-radiography-database/COVID-19_Radiography_Dataset/Normal'

for image in os.listdir(COVID_TEST)[:100]:
    shutil.copy(os.path.join(COVID_TEST, image), os.path.join('./COVID19-DATASET/test/covid19', image))
for image in os.listdir(NORMAL_TEST)[:100]:
    shutil.copy(os.path.join(NORMAL_TEST, image), os.path.join('./COVID19-DATASET/test/normal', image))

TEST_PATH = '/content/COVID19-DATASET/test'
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3641, done.
# remote: Total 3641 (delta 0), reused 0 (delta 0), pack-reused 3641
# Receiving objects: 100% (3641/3641), 632.96 MiB | 21.28 MiB/s, done.
# Resolving deltas: 100% (1450/1450), done.
# Checking out files: 100% (1174/1174), done.
# TRAIN_PATH: /content/COVID19-DATASET/train

# %% [markdown]
# # Retrieve code

# %%
import sys
# !git clone https://github.com/Michaeltaoma/SecureCovid.git
# %cd SecureCovid
# !git checkout dev
sys.path.append("/content/SecureCovid")
# Out:
# Cloning into 'SecureCovid'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 206 (delta 105), reused 138 (delta 50), pack-reused 0
# Receiving objects: 100% (206/206), 85.92 KiB | 8.59 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /content/SecureCovid
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %% [markdown]
# # Train

# %%
# !python /content/SecureCovid/shadow_train.py --model "covidnet"
# Out:
# Training on CPU... May the force be with you...
# CovidNet(
#   (conv1): Conv2d(3, 56, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (pepx1_1): PEPX(
#     (network): Sequential(
#       (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#       (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx1_2): PEPX(
#     (network): Sequential(
#       (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#       (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx1_3): PEPX(
#     (network): Sequential(
#       (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#       (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx2_1): PEPX(
#     (network): Sequential(
#       (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#       (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(28, 112, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx2_2): PEPX(
#     (network): Sequential(
#       (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#       (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx2_3): PEPX(
#     (network): Sequential(
#       (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#       (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx2_4): PEPX(
#     (network): Sequential(
#       (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#       (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_1): PEPX(
#     (network): Sequential(
#       (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#       (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(56, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_2): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_3): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_4): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_5): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx3_6): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx4_1): PEPX(
#     (network): Sequential(
#       (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#       (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(108, 424, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx4_2): PEPX(
#     (network): Sequential(
#       (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#       (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (pepx4_3): PEPX(
#     (network): Sequential(
#       (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#       (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#       (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#       (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (flatten): Flatten()
#   (fc1): Linear(in_features=20776, out_features=512, bias=True)
#   (classifier): Linear(in_features=512, out_features=2, bias=True)
# )
# Conv2d(3, 56, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#     (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#   (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
# Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#     (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#   (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
# Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#     (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#   (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
# Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 56, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#     (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(28, 112, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
#   (3): Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(28, 112, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(56, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 42, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(42, 42, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=42)
# Conv2d(42, 28, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(28, 112, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#     (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#   (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
# Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#     (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#   (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
# Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#     (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#   (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
# Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 112, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#     (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(56, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
#   (3): Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(56, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(112, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 84, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(84, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=84)
# Conv2d(84, 56, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(56, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 216, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#     (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(108, 424, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
#   (3): Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(108, 424, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(216, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 162, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(162, 162, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=162)
# Conv2d(162, 108, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(108, 424, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#     (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#   (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
# Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# PEPX(
#   (network): Sequential(
#     (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#     (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#     (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#     (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#     (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Sequential(
#   (0): Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
#   (1): Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
#   (2): Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
#   (3): Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
#   (4): Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
#   (5): BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Conv2d(424, 212, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(212, 318, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(318, 318, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=318)
# Conv2d(318, 212, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(212, 424, kernel_size=(1, 1), stride=(1, 1))
# BatchNorm2d(424, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# Flatten()
# Linear(in_features=20776, out_features=512, bias=True)
# Linear(in_features=512, out_features=2, bias=True)
# Epoch 1/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:663: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# train Loss: 6.0804 | train Accuracy: 0.8755
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 3.0480 | val Accuracy: 0.8906 | Kappa Score: 0.7911
# Val loss Decreased from inf to 3.0480
# Saving Weights...
#
# Epoch 2/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 2.4283 | train Accuracy: 0.9086
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.7716 | val Accuracy: 0.8906 | Kappa Score: 0.7525
# Val loss Decreased from 3.0480 to 2.7716
# Saving Weights...
#
# Epoch 3/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:663: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# train Loss: 2.4911 | train Accuracy: 0.9105
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.5001 | val Accuracy: 0.8828 | Kappa Score: 0.7297
# Val loss Decreased from 2.7716 to 2.5001
# Saving Weights...
#
# Epoch 4/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 2.5103 | train Accuracy: 0.9066
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.7157 | val Accuracy: 0.8828 | Kappa Score: 0.7473
#
# Epoch 5/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 2.8104 | train Accuracy: 0.9105
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.7073 | val Accuracy: 0.8906 | Kappa Score: 0.7585
#
# Epoch 6/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 2.4301 | train Accuracy: 0.9125
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.4766 | val Accuracy: 0.8828 | Kappa Score: 0.7660
# Val loss Decreased from 2.5001 to 2.4766
# Saving Weights...
#
# Epoch 7/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 3.2568 | train Accuracy: 0.8969
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.5707 | val Accuracy: 0.8828 | Kappa Score: 0.7437
#
# Epoch 8/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 2.4776 | train Accuracy: 0.9202
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.6750 | val Accuracy: 0.8828 | Kappa Score: 0.7426
#
# Epoch 9/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# train Loss: 3.3042 | train Accuracy: 0.8833
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.2133 | val Accuracy: 0.8906 | Kappa Score: 0.7226
# Val loss Decreased from 2.4766 to 2.2133
# Saving Weights...
#
# Epoch 10/10
# ----------
# train:   0%|          | 0/65 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:663: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# train Loss: 2.7577 | train Accuracy: 0.9047
# val:   0%|          | 0/16 [00:00<?, ?it/s]
# val Loss: 2.5187 | val Accuracy: 0.8906 | Kappa Score: 0.7696
#
# Training complete in 17m 39s
# Best val loss: 2.2133
# Shadow Model saved to /content/drive/MyDrive/MEDICAL/trained/train_best_shadow_1647198485.4663925.pth
